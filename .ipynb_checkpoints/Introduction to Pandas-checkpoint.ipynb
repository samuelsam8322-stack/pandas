# %% [markdown]
# # What is Pandas?

# %%
 Pandas is a python library used for working with data. it helps you load,clean, organize, analyze and manipulate data easily.
Its helps us work with:
   1. Tables of data
   2. Excel files
   3. CSV files
   4. SQL Data
   5. Large dataset

# %%
# Main structures:

  *Series
  *DataFrame

# %% [markdown]
# # 1. Series in Pandas
# A Series is a one-dimensional labeled array.
#
# It stores:
#
# Single column of # data Index + values

# %%
s = pd.Series([10, 20, 30, 40])

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([100, 200, 300], index=["a", "b", "c"])
print(s)
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# # DATA FRAMES

# %%
data = {
    "Name": ["Sam", "John", "Anna"],
    "Age": [21, 22, 20]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Name  Age
# 0   Sam   21
# 1  John   22
# 2  Anna   20

# %% [markdown]
# # 2.loc[] in Pandas
#
# loc[] is used for:
#
# Label-based selection
# Row and column names

# %%
df.loc[row_label, column_label]

# %%
print(df.loc[0])
# Out:
# Name    Sam
# Age      21
# Name: 0, dtype: object

# %%
print(df.loc[1, "Name"])
# Out:
# John

# %% [markdown]
# # 3.iloc[] in Pandas
#
# iloc[] is used for:
#
# Position-based indexing
# Integer positions

# %%
df.iloc[row_index, column_index]

# %%
print(df.iloc[0])
# Out:
# Name    Sam
# Age      21
# Name: 0, dtype: object

# %%
print(df.iloc[1, 0])

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\si310\OneDrive\Desktop\Pandas\archive (1)\Employee_Complete_Dataset.csv")
data
# Out:
#        Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 0                10001  Karen Anderson            36             True
# 1                10002    David Taylor            34            False
# 2                10003      Nina Kumar            36            False
# 3                10004      John Patel            42             True
# 4                10005    Emily Sharma            27             True
# ...                ...             ...           ...              ...
# 49995            59996    Olivia Singh            34             True
# 49996            59997  Rohit Anderson            63            False
# 49997            59998   Olivia Taylor            39             True
# 49998            59999      Luke Brown            40             True
# 49999            60000     Arun Thomas            42            False
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data.shape                                                           # shape
# Out:
# (50000, 19)

# %%
data.info()                                                          # info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_number     50000 non-null  int64
#  1   Employee_name       50000 non-null  str
#  2   Employee_age        50000 non-null  int64
#  3   Maritial_Status     50000 non-null  bool
#  4   Current_Salary      50000 non-null  int64
#  5   Number_of_Children  50000 non-null  int64
#  6   years_experience    50000 non-null  int64
#  7   past_projects       50000 non-null  int64
#  8   current_projects    50000 non-null  int64
#  9   Divorced_earlier    50000 non-null  str
#  10  Father_alive        50000 non-null  str
#  11  Mother_alive        50000 non-null  str
#  12  performance_rating  50000 non-null  int64
#  13  Education_level     50000 non-null  str
#  14  Department          50000 non-null  str
#  15  Role                50000 non-null  str
# ...

# %%
import numpy as np

# %%
data.describe(include = [np.number])
# Out:
#        Employee_number  Employee_age  Current_Salary  Number_of_Children  \
# count     50000.000000  50000.000000    50000.000000         50000.00000
# mean      35000.500000     34.704800    58396.139100             1.19564
# std       14433.901067      9.607357    31415.294557             1.12194
# min       10001.000000     16.000000    15128.000000             0.00000
# 25%       22500.750000     28.000000    33581.000000             0.00000
# 50%       35000.500000     35.000000    53029.000000             1.00000
# 75%       47500.250000     41.000000    73750.000000             2.00000
# max       60000.000000     85.000000   695267.000000             3.00000
#
#        years_experience  past_projects  current_projects  performance_rating  \
# count      50000.000000   50000.000000       50000.00000        50000.000000
# mean           8.301700       7.013640           1.50094            3.198300
# std            8.632958       4.325417           1.11543            0.981854
# ...

# %%
data.head                                                 # head
# Out:
# <bound method NDFrame.head of        Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 0                10001  Karen Anderson            36             True
# 1                10002    David Taylor            34            False
# 2                10003      Nina Kumar            36            False
# 3                10004      John Patel            42             True
# 4                10005    Emily Sharma            27             True
# ...                ...             ...           ...              ...
# 49995            59996    Olivia Singh            34             True
# 49996            59997  Rohit Anderson            63            False
# 49997            59998   Olivia Taylor            39             True
# 49998            59999      Luke Brown            40             True
# 49999            60000     Arun Thomas            42            False
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data.tail                                                  # tail
# Out:
# <bound method NDFrame.tail of        Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 0                10001  Karen Anderson            36             True
# 1                10002    David Taylor            34            False
# 2                10003      Nina Kumar            36            False
# 3                10004      John Patel            42             True
# 4                10005    Emily Sharma            27             True
# ...                ...             ...           ...              ...
# 49995            59996    Olivia Singh            34             True
# 49996            59997  Rohit Anderson            63            False
# 49997            59998   Olivia Taylor            39             True
# 49998            59999      Luke Brown            40             True
# 49999            60000     Arun Thomas            42            False
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data.isnull().sum()                                       # isnull().sum()
# Out:
# Employee_number       0
# Employee_name         0
# Employee_age          0
# Maritial_Status       0
# Current_Salary        0
# Number_of_Children    0
# years_experience      0
# past_projects         0
# current_projects      0
# Divorced_earlier      0
# Father_alive          0
# Mother_alive          0
# performance_rating    0
# Education_level       0
# Department            0
# Role                  0
# Job_Satisfaction      0
# Work_Life_Balance     0
# is_outlier            0
# dtype: int64

# %%
data

# %%
import pandas as pd
import numpy as np

data = {
    "ID": [1, 2, 3, 4, 4],
    "Name": ["Sam", "John", "Anu", "Ravi", "Ravi"],
    "Age": [22, 25, np.nan, 28, 28],
    "City": ["Chennai", "Delhi", "Mumbai", None, None]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN

# %%
print(df.shape)                                                      # shape
# Out:
# (5, 4)

# %%
print(df.info())                                                     # info
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      str
#  2   Age     4 non-null      float64
#  3   City    3 non-null      str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 292.0 bytes
# None

# %%
print(df.describe())                                                 # describe
# Out:
#             ID        Age
# count  5.00000   4.000000
# mean   2.80000  25.750000
# std    1.30384   2.872281
# min    1.00000  22.000000
# 25%    2.00000  24.250000
# 50%    3.00000  26.500000
# 75%    4.00000  28.000000
# max    4.00000  28.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      str
#  2   Age     4 non-null      float64
#  3   City    3 non-null      str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 292.0 bytes

# %%
df.head()                                                                    # head
# Out:
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN

# %%
df.tail()                                                                  # tail
# Out:
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN

# %%
df["Salary"] = [30000, 40000, 35000, 45000, 45000]
                                                                               # add column
print(df)
# Out:
#    ID  Name   Age     City  Salary
# 0   1   Sam  22.0  Chennai   30000
# 1   2  John  25.0    Delhi   40000
# 2   3   Anu   NaN   Mumbai   35000
# 3   4  Ravi  28.0      NaN   45000
# 4   4  Ravi  28.0      NaN   45000

# %%
df.drop("Salary", axis=1, inplace=True)
                                                                             # remove column
print(df)
# Out:
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN

# %%
print(df.isnull())                                                           # is null
# Out:
#       ID   Name    Age   City
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False   True  False
# 3  False  False  False   True
# 4  False  False  False   True

# %%
print(df.isnull().sum())                                                     # is null(). sum()
# Out:
# ID      0
# Name    0
# Age     1
# City    2
# dtype: int64

# %%
new_df = df.dropna()
                                                                            # dropna() - drop null values
print(new_df)
# Out:
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi

# %%
df.drop(0, axis=0, inplace=True)
                                                                             # drop index with axis
print(df)
# Out:
#    ID  Name   Age    City
# 1   2  John  25.0   Delhi
# 2   3   Anu   NaN  Mumbai
# 3   4  Ravi  28.0     NaN
# 4   4  Ravi  28.0     NaN

# %%
df.drop("City", axis=1, inplace=True)
                                                                             # drop column with axis
print(df)
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN
# 3   4  Ravi  28.0
# 4   4  Ravi  28.0

# %%
print(df.duplicated())                                                       # duplicates
# Out:
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df2 = df.drop_duplicates()
                                                                           # remove duplicates
print(df2)
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN
# 3   4  Ravi  28.0

# %%
df.drop_duplicates(keep='first')                                           # keep = first
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN
# 3   4  Ravi  28.0

# %%
df.drop_duplicates(keep='last')                                            # keep = last
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN
# 4   4  Ravi  28.0

# %%
df.drop_duplicates(keep=False)                                            # keep = False
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN

# %%
df.drop_duplicates(subset=["Name"])                                     # remove duplicates using subset
# Out:
#    ID  Name   Age
# 1   2  John  25.0
# 2   3   Anu   NaN
# 3   4  Ravi  28.0

# %%
import pandas as pd
import numpy as np

data = {
    "ID": [1, 2, 3, 4, 4],
    "Name": ["Sam", "John", "Anu", "Ravi", "Ravi"],
    "Age": [22, 25, np.nan, 28, 28],
    "City": ["Chennai", "Delhi", "Mumbai", None, None]
}

df = pd.DataFrame(data)

print(df.shape)
print(df.info())
print(df.describe())
print(df.head())
print(df.tail())

df["Salary"] = [30000, 40000, 35000, 45000, 45000]

print(df.isnull())
print(df.isnull().sum())

print(df.dropna())

print(df.duplicated())

print(df.drop_duplicates())

print(df.drop_duplicates(keep='last'))

print(df.drop_duplicates(subset=["Name"]))
# Out:
# (5, 4)
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      5 non-null      int64
#  1   Name    5 non-null      str
#  2   Age     4 non-null      float64
#  3   City    3 non-null      str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 292.0 bytes
# None
#             ID        Age
# count  5.00000   4.000000
# mean   2.80000  25.750000
# std    1.30384   2.872281
# min    1.00000  22.000000
# 25%    2.00000  24.250000
# 50%    3.00000  26.500000
# 75%    4.00000  28.000000
# max    4.00000  28.000000
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN
#    ID  Name   Age     City
# 0   1   Sam  22.0  Chennai
# 1   2  John  25.0    Delhi
# 2   3   Anu   NaN   Mumbai
# 3   4  Ravi  28.0      NaN
# 4   4  Ravi  28.0      NaN
# ...

# %%
data = {
    "id": [1, 2, 3, 4],
    "name": ["sam", "john", "anu", np.nan],
    "age": [22, 25, np.nan, 28],
    "city": ["chennai", "delhi", "mumbai", "pune"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    id  name   age     city
# 0   1   sam  22.0  chennai
# 1   2  john  25.0    delhi
# 2   3   anu   NaN   mumbai
# 3   4   NaN  28.0     pune

# %%
df["age"] = df["age"].fillna(0)
                                                                                # fillna (fill string)
print(df)
# Out:
#    id  name   age     city
# 0   1   sam  22.0  chennai
# 1   2  john  25.0    delhi
# 2   3   anu   0.0   mumbai
# 3   4   NaN  28.0     pune

# %%
df["name"] = df["name"].fillna("unknown")
                                                                                # fill string na 
print(df)
# Out:
#    id     name   age     city
# 0   1      sam  22.0  chennai
# 1   2     john  25.0    delhi
# 2   3      anu   0.0   mumbai
# 3   4  unknown  28.0     pune

# %%
df["age"] = df["age"].astype(int)
                                                                              # as type
print(df.dtypes)
# Out:
# id      int64
# name      str
# age     int64
# city      str
# dtype: object

# %%
print(df.columns)                                                            # columns
# Out:
# Index(['id', 'name', 'age', 'city'], dtype='str')

# %%
df.columns = df.columns.str.upper()
                                                                             # columns string UPPER
print(df.columns)
# Out:
# Index(['ID', 'NAME', 'AGE', 'CITY'], dtype='str')

# %%
df.columns = df.columns.str.lower()
                                                                             # columns string lower
print(df.columns)
# Out:
# Index(['id', 'name', 'age', 'city'], dtype='str')

# %%
df.rename(columns={"name": "student_name"}, inplace=True)
                                                                             # rename 
print(df)
# Out:
#    id student_name  age     city
# 0   1          sam   22  chennai
# 1   2         john   25    delhi
# 2   3          anu    0   mumbai
# 3   4      unknown   28     pune

# %%
df.rename(columns={
    "age": "student_age",
    "city": "location"
}, inplace=True)
                                                                           # rename multiple columns
print(df)
# Out:
#    id student_name  student_age location
# 0   1          sam           22  chennai
# 1   2         john           25    delhi
# 2   3          anu            0   mumbai
# 3   4      unknown           28     pune

# %%
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["sam", "john", "anu"]                                          # creating 1st data
})

print(df1)
# Out:
#    id  name
# 0   1   sam
# 1   2  john
# 2   3   anu

# %%
df2 = pd.DataFrame({
    "id": [1, 2, 3],
    "salary": [30000, 40000, 50000]                                         # creating 2nd data
})

print(df2)
# Out:
#    id  salary
# 0   1   30000
# 1   2   40000
# 2   3   50000

# %%
result = pd.merge(df1, df2, on="id")
                                                                                   # merge
print(result)
# Out:
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %% [markdown]
# Types of Merge

# %%
pd.merge(df1, df2, on="id", how="inner")                                   # inner merge
# Out:
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %%
pd.merge(df1, df2, on="id", how="left")                                  # left merge
# Out:
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %%
pd.merge(df1, df2, on="id", how="right")                                 # right merge
# Out:
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %%
pd.merge(df1, df2, on="id", how="outer")                                # outer merge
# Out:
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %%
import pandas as pd
import numpy as np

data = {
    "id": [1, 2, 3, 4],
    "name": ["sam", "john", "anu", np.nan],
    "age": [22, 25, np.nan, 28],
    "city": ["chennai", "delhi", "mumbai", "pune"]
}

df = pd.DataFrame(data)

# fillna
df["age"] = df["age"].fillna(0)
df["name"] = df["name"].fillna("unknown")

# astype
df["age"] = df["age"].astype(int)

# columns
print(df.columns)

# upper
df.columns = df.columns.str.upper()

# lower
df.columns = df.columns.str.lower()

# rename
df.rename(columns={"name": "student_name"}, inplace=True)

print(df)

# merge
df1 = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["sam", "john", "anu"]
})

df2 = pd.DataFrame({
    "id": [1, 2, 3],
    "salary": [30000, 40000, 50000]
})

result = pd.merge(df1, df2, on="id")

print(result)
# Out:
# Index(['id', 'name', 'age', 'city'], dtype='str')
#    id student_name  age     city
# 0   1          sam   22  chennai
# 1   2         john   25    delhi
# 2   3          anu    0   mumbai
# 3   4      unknown   28     pune
#    id  name  salary
# 0   1   sam   30000
# 1   2  john   40000
# 2   3   anu   50000

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\si310\OneDrive\Desktop\Pandas\archive (1)\Employee_Test_Dataset.csv")
data
# Out:
#       Employee_number    Employee_name  Employee_age  Maritial_Status  \
# 0               43554    Ananya Miller            31             True
# 1               19428     Olivia Gupta            30            False
# 2               10200  Daniel Williams            29            False
# 3               22448     Aisha Miller            27            False
# 4               49490     Sarah Thomas            46            False
# ...               ...              ...           ...              ...
# 4995            49886     Aisha Taylor            43            False
# 4996            27567    Michael Lewis            38             True
# 4997            26063   Aisha Williams            31             True
# 4998            58446      Priya Singh            33            False
# 4999            30383       Leo Sharma            42             True
#
#       Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data2 = pd.read_csv(r"C:\Users\si310\OneDrive\Desktop\Pandas\archive (1)\Employee_Train_Dataset.csv")
data2
# Out:
#        Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 0                50878    Priya Sharma            49             True
# 1                28058     Rohit Smith            47            False
# 2                29067   Michael Patel            41            False
# 3                30526    Daniel Smith            38             True
# 4                15848  Linda Thompson            29             True
# ...                ...             ...           ...              ...
# 44995            21285   Rohit Johnson            55             True
# 44996            54733    Emily Sharma            49             True
# 44997            48159     Rohit Davis            34             True
# 44998            10861     David Davis            21             True
# 44999            25796   Nina Thompson            33            False
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
pd.concat((data,data2), axis =1)                                                  # concat with axis=1
# Out:
#        Employee_number    Employee_name  Employee_age Maritial_Status  \
# 0              43554.0    Ananya Miller          31.0            True
# 1              19428.0     Olivia Gupta          30.0           False
# 2              10200.0  Daniel Williams          29.0           False
# 3              22448.0     Aisha Miller          27.0           False
# 4              49490.0     Sarah Thomas          46.0           False
# ...                ...              ...           ...             ...
# 44995              NaN              NaN           NaN             NaN
# 44996              NaN              NaN           NaN             NaN
# 44997              NaN              NaN           NaN             NaN
# 44998              NaN              NaN           NaN             NaN
# 44999              NaN              NaN           NaN             NaN
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
pd.concat((data,data2),axis = 0)                                              # concat with axis = 0
# Out:
#        Employee_number    Employee_name  Employee_age  Maritial_Status  \
# 0                43554    Ananya Miller            31             True
# 1                19428     Olivia Gupta            30            False
# 2                10200  Daniel Williams            29            False
# 3                22448     Aisha Miller            27            False
# 4                49490     Sarah Thomas            46            False
# ...                ...              ...           ...              ...
# 44995            21285    Rohit Johnson            55             True
# 44996            54733     Emily Sharma            49             True
# 44997            48159      Rohit Davis            34             True
# 44998            10861      David Davis            21             True
# 44999            25796    Nina Thompson            33            False
#
#        Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %% [markdown]
# SORT VALUES & SORT INDEX

# %%
data = pd.read_csv(r"C:\Users\si310\OneDrive\Desktop\Pandas\archive (1)\Employee_Test_Dataset.csv")
data
# Out:
#       Employee_number    Employee_name  Employee_age  Maritial_Status  \
# 0               43554    Ananya Miller            31             True
# 1               19428     Olivia Gupta            30            False
# 2               10200  Daniel Williams            29            False
# 3               22448     Aisha Miller            27            False
# 4               49490     Sarah Thomas            46            False
# ...               ...              ...           ...              ...
# 4995            49886     Aisha Taylor            43            False
# 4996            27567    Michael Lewis            38             True
# 4997            26063   Aisha Williams            31             True
# 4998            58446      Priya Singh            33            False
# 4999            30383       Leo Sharma            42             True
#
#       Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data.sort_values('Current_Salary',ascending = True)
# Out:
#       Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 1259            52437    Daniel Davis            52             True
# 14              28472    Priya Wilson            27            False
# 3079            55145     Emily Brown            54             True
# 11              48696   Emily Johnson            30             True
# 3278            59129    Daniel Singh            33            False
# ...               ...             ...           ...              ...
# 4372            47079     John Thomas            35             True
# 4457            28973        Leo Iyer            22             True
# 2634            41062  Michael Sharma            29             True
# 3946            40343  Daniel Johnson            36             True
# 1036            52285     Aisha Lewis            21            False
#
#       Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_number     5000 non-null   int64
#  1   Employee_name       5000 non-null   str
#  2   Employee_age        5000 non-null   int64
#  3   Maritial_Status     5000 non-null   bool
#  4   Current_Salary      5000 non-null   int64
#  5   Number_of_Children  5000 non-null   int64
#  6   years_experience    5000 non-null   int64
#  7   past_projects       5000 non-null   int64
#  8   current_projects    5000 non-null   int64
#  9   Divorced_earlier    5000 non-null   str
#  10  Father_alive        5000 non-null   str
#  11  Mother_alive        5000 non-null   str
#  12  performance_rating  5000 non-null   int64
#  13  Education_level     5000 non-null   str
#  14  Department          5000 non-null   str
#  15  Role                5000 non-null   str
# ...

# %%
data.sort_values('Current_Salary', ascending = False)
# Out:
#       Employee_number   Employee_name  Employee_age  Maritial_Status  \
# 1036            52285     Aisha Lewis            21            False
# 3946            40343  Daniel Johnson            36             True
# 2634            41062  Michael Sharma            29             True
# 4457            28973        Leo Iyer            22             True
# 4372            47079     John Thomas            35             True
# ...               ...             ...           ...              ...
# 3278            59129    Daniel Singh            33            False
# 11              48696   Emily Johnson            30             True
# 3079            55145     Emily Brown            54             True
# 14              28472    Priya Wilson            27            False
# 1259            52437    Daniel Davis            52             True
#
#       Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %% [markdown]
# # OUTLIERS, SKEWNESS, KURTOSIS

# %% [markdown]
# # 1. OUTLIERS:

# %%
An outlier is a value that is very different from other values in the dataset.

# Two types: IQR -InterQuartile Range
#            Z-score

    Detect Outliers Using IQR Method
#Formula:
IQR = Q3 - Q1
Lower Limit = Q1 - 1.5 × IQR
Upper Limit = Q3 + 1.5 × IQR

# %%
Q1 = data['Employee_age'].quantile(0.25)
Q3 = data['Employee_age'].quantile(0.75)

# %%
Q1,Q3
# Out:
# (np.float64(28.0), np.float64(41.0))

# %%
IQR = Q3 - Q1
IQR
# Out:
# np.float64(13.0)

# %%
lower_outlier = Q1 - 1.5*IQR
upper_outlier = Q3 + 1.5*IQR

lower_outlier
upper_outlier
# Out:
# np.float64(60.5)

# %%
data[(data['Employee_age']< lower_outlier) | (data['Employee_age']>upper_outlier)]
# Out:
#       Employee_number    Employee_name  Employee_age  Maritial_Status  \
# 159             16021     David Sharma            63             True
# 203             58578      David Kumar            61            False
# 207             56639       Arun Smith            62             True
# 396             37239  Vikram Williams            61             True
# 484             11823      Sarah Kumar            61             True
# 687             23702    Vikram Walker            61            False
# 769             23642    Daniel Walker            61             True
# 1339            14520   Kiran Williams            61             True
# 1444            13378     Sarah Sharma            65             True
# 1503            21402     Ananya Singh            61             True
# 1539            29105      Karen Brown            65             True
# 1588            54918    Nina Williams            62             True
# ...

# %%
data = data[(data['Employee_age']> lower_outlier) & (data['Employee_age']<upper_outlier)]
data
# Out:
#       Employee_number    Employee_name  Employee_age  Maritial_Status  \
# 0               43554    Ananya Miller            31             True
# 1               19428     Olivia Gupta            30            False
# 2               10200  Daniel Williams            29            False
# 3               22448     Aisha Miller            27            False
# 4               49490     Sarah Thomas            46            False
# ...               ...              ...           ...              ...
# 4995            49886     Aisha Taylor            43            False
# 4996            27567    Michael Lewis            38             True
# 4997            26063   Aisha Williams            31             True
# 4998            58446      Priya Singh            33            False
# 4999            30383       Leo Sharma            42             True
#
#       Current_Salary  Number_of_Children  years_experience  past_projects  \
# ...

# %% [markdown]
# # 2. SKEWNESS

# %%
Skewness tells whether data is symmetric or not.( or To know about data spread)

# Types of Skewness
Positive Skew (Right Skew) - Tail is towards the right side.
Negative Skew (Left Skew) - Tail is towards the left side.
Symmetric Distribution - Mean ≈ Median
                                                         df.skew()

# %%
# print(df["Marks"].skew())
data["Employee_age"].skew()
# Out:
# np.float64(0.1563193840931975)

# %%
data['Current_Salary'].skew()
# Out:
# np.float64(6.939790206347164)

# %% [markdown]
#  # 3. KURTOSIS

# %%
Kurtosis measures the peakedness of data and presence of outliers (it measures the 'Tailedness'.It tells you how much of
your data lies in the tail).

#Types of Kurtosis:
1.Leptokurtic
      High peak
      More outliers
      Kurtosis > 0
2.Mesokurtic
      Normal distribution
      Kurtosis = 0
3.Platykurtic
     Flat distribution
     Fewer outliers
     Kurtosis < 0
                                                      print(df["Marks"].kurt())

# %%
data["Employee_age"].kurt()
# Out:
# np.float64(-0.5508866885169037)

# %%
data['Current_Salary'].kurt()
# Out:
# np.float64(102.37584261133019)

# %% [markdown]
# # GROUP BY

# %%
groupby() is used to group similar data together and perform operations like:

sum()
mean()
count()
max()
min()

It works similar to SQL GROUP BY.

# %%
df.groupby("column_name")

# %%
data.groupby('Department')['Current_Salary'].mean()
# Out:
# Department
# Engineering    58572.447619
# Finance        59795.496484
# HR             58271.770370
# Operations     58897.046942
# R&D            56682.881119
# Sales          58539.175103
# Support        58207.700000
# Name: Current_Salary, dtype: float64

# %% [markdown]
# Multiple Group By

# %%
data.groupby('Department').agg({'Current_Salary':['mean','max','min'], 'years_experience':'sum'})
# Out:
#             Current_Salary                years_experience
#                       mean     max    min              sum
# Department
# Engineering   58572.447619  387822  30000             5915
# Finance       59795.496484  638897  30000             6031
# HR            58271.770370  645242  21092             5643
# Operations    58897.046942  615845  30000             5631
# R&D           56682.881119  680490  16645             6222
# Sales         58539.175103  634419  30000             5904
# Support       58207.700000  266319  20432             5525

# %%
import matplotlib.pyplot as plt
data.groupby('Department').agg({'Current_Salary':['mean','max','min'], 'years_experience':'sum'}).plot(kind = 'hist', title = 'Yrs Exp')
plt.ylabel('years_experience')
plt.show()

# %% [markdown]
# Pivot Table:

# %% [markdown]
# A Pivot Table in Excel is a powerful tool that lets you summarize, analyze, and explore large amounts of data without writing formulas.
#
# Think of it as a way to answer questions like:
#
# How much did each salesperson sell?
# What are total sales by month?
# Which product category generated the most revenue?
# How many orders came from each region?

# %% [markdown]
# # Matplotlib Correlation:

# %%
Correlation measures the relationship between two variables.

+1 → Perfect positive correlation
0 → No correlation
-1 → Perfect negative correlation

Matplotlib itself does not calculate correlation. Usually, you calculate correlation using NumPy or Pandas, 
and then visualize it using Matplotlib.

# %%
# Example 1: Scatter Plot to Visualize Correlation

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 5, 4, 5]

plt.scatter(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Correlation Scatter Plot")
plt.show()

# %% [markdown]
# A scatter plot helps you see whether points move together (positive correlation), apart (negative correlation),
# or randomly (no correlation).

# %%
# Example 2: Calculate Correlation with NumPy

import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

corr = np.corrcoef(x, y)

print(corr)
# Out:
# [[1.         0.77459667]
#  [0.77459667 1.        ]]

# %%
#Example 3: Display Correlation on a Plot 

import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
y = np.array([2,4,5,4,5])

corr = np.corrcoef(x, y)[0,1]

plt.scatter(x, y)
plt.title(f"Correlation = {corr:.2f}")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#Example 4: Correlation Matrix with Pandas

import pandas as pd

data = {
    'Math': [70, 80, 90, 60, 75],
    'Science': [65, 85, 95, 55, 70],
    'English': [80, 75, 85, 70, 90]
}

df = pd.DataFrame(data)

print(df.corr())
# Out:
#              Math   Science   English
# Math     1.000000  0.980196  0.565685
# Science  0.980196  1.000000  0.396059
# English  0.565685  0.396059  1.000000

# %% [markdown]
# Interpretation:

# %%
#Correlation (r)	                   Meaning

1.0	                           Perfect Positive
0.7 to 0.9	                   Strong Positive
0.3 to 0.7	                   Moderate Positive
0	                           No Correlation
-0.3 to -0.7	               Moderate Negative
-0.7 to -0.9	               Strong Negative
-1.0	                       Perfect Negative

In data analytics, the most common approach is:
1.Calculate correlation using df.corr() or np.corrcoef().
2.Visualize the relationship using a Matplotlib scatter plot.
3.Interpret the correlation coefficient to understand how strongly the variables are related.
